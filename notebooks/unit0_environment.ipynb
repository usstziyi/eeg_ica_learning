# %% [markdown]
# # Unit 0：环境准备
#
# ## 目标
# - 安装 MNE-Python
# - 下载 mne-sample-data 数据集
# - 验证环境可用

# %% [markdown]
# ### 0.1 安装 MNE
#
# 在终端运行（二选一）：
# ```bash
# uv add mne scikit-learn
# uv add -dev notebook
# ```

# %%
import mne
import numpy as np
import os
# %matplotlib inline
from matplotlib import pyplot as plt

print(f"MNE 版本: {mne.__version__}")
print(f"NumPy 版本: {np.__version__}")
print("✅ 环境检查通过！")
mne.sys_info()
# Out:
# MNE 版本: 1.12.1
# NumPy 版本: 2.4.4
# ✅ 环境检查通过！
# Platform             macOS-26.4.1-arm64-arm-64bit-Mach-O
# Python               3.14.4 (main, Apr 14 2026, 14:46:33) [Clang 22.1.3 ]
# Executable           /Users/usst_ziyi/Programs/trae/EEG/eeg_ica_learning/.venv/bin/python
# CPU                  Apple M2 (8 cores)
# Memory               8.0 GiB
#
# Core
# ├☑ mne               1.12.1 (unable to check for latest version on GitHub, unknown error: HTTP Error 403: rate limit exceeded)
# ├☑ numpy             2.4.4 (unknown linalg bindings)
# ├☑ scipy             1.17.1
# └☑ matplotlib        3.10.9 (backend=inline)
#
# Numerical (optional)
# ├☑ sklearn           1.8.0
# ├☑ nibabel           5.4.2
# ├☑ pandas            3.0.2
# ├☑ h5py              3.16.0
# └☐ unavailable       numba, nilearn, dipy, openmeeg, cupy, h5io
#
# Visualization (optional)
# ├☑ pyvista           0.48.0 (OpenGL 4.1 Metal - 90.5 via Apple M2)
# ├☑ pyvistaqt         0.11.4
# ├☑ vtk               9.6.1
# ├☑ qtpy              2.4.3 (PyQt6=6.11.0)
# ├☑ ipympl            0.10.0
# ├☑ pyqtgraph         0.14.0
# ├☑ mne-qt-browser    0.7.4
# ├☑ ipywidgets        8.1.8
# └☐ unavailable       trame_client, trame_server, trame_vtk, trame_vuetify
#
# Ecosystem (optional)
# ├☑ mne-bids          0.18.0
# ├☑ edfio             0.4.13
# ├☑ pybv              0.7.6
# ├☑ defusedxml        0.7.1
# └☐ unavailable       mne-nirs, mne-features, mne-connectivity, mne-icalabel, mne-bids-pipeline, neo, eeglabio, curryreader, mffpy, pymef, antio

# %% [markdown]
# ### 0.2 下载 sample data
#
# 首次运行会下载约 1.5GB 数据。

# %%
data_dir = os.path.abspath("./../datasets")
os.makedirs(data_dir, exist_ok=True)
mne.set_config("MNE_DATA", data_dir)
mne.set_config("MNE_DATASETS_SAMPLE_PATH", data_dir)

sample_data_dir = mne.datasets.sample.data_path()
print(f"Sample data 路径: {sample_data_dir}")
# 创建电极位置模板
montage = mne.channels.make_standard_montage('standard_1020')
print(f"Montage 通道数: {len(montage.ch_names)}")
# Out:
# Sample data 路径: /Users/usst_ziyi/Programs/trae/EEG/eeg_ica_learning/datasets/MNE-sample-data
# Montage 通道数: 94

# %% [markdown]
# ### 0.3 预览原始数据
#
# > ⚠️ 注意：本数据集的 EEG 通道命名为 `EEG 001`、`EEG 002`... 而非标准的 Fp1、Cz 等。
# > 这是 MNE sample data 的历史命名方式，不影响使用。

# %%
raw_fname = sample_data_dir / 'MEG' / 'sample' / 'sample_audvis_raw.fif'
raw = mne.io.read_raw_fif(raw_fname, preload=False)
print(raw)
print(f"采样率: {raw.info['sfreq']} Hz  |  通道数: {len(raw.ch_names)}  |  时长: {raw.times[-1]:.0f}s")
# 只看 EEG 通道
raw_eeg = raw.copy().pick(['eeg'])
print(f"EEG 通道（前5个）: {raw_eeg.ch_names[:5]}...")
# Out:
# Opening raw data file /Users/usst_ziyi/Programs/trae/EEG/eeg_ica_learning/datasets/MNE-sample-data/MEG/sample/sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# <Raw | sample_audvis_raw.fif, 376 x 166800 (277.7 s), ~3.2 MiB, data not loaded>
# 采样率: 600.614990234375 Hz  |  通道数: 376  |  时长: 278s
# EEG 通道（前5个）: ['EEG 001', 'EEG 002', 'EEG 003', 'EEG 004', 'EEG 005']...

# %%
# 可视化前 60 秒
raw_eeg.plot(n_channels=10, scalings='auto', title='EEG original data (60s)')
# Out:
# Using qt as 2D backend.
# Channels marked as bad:
# ['EEG 053']

# %% [markdown]
# ### ✅ Unit 0 完成！
#
# 继续 → **Unit 1：ICA 数学直觉**
